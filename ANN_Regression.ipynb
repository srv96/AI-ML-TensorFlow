# %% [markdown]
# <a href="https://colab.research.google.com/github/srv96/AI-ML-TensorFlow/blob/main/ANN_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
N = 1000
X = np.random.random((N,2)) * 6 - 3
y = np.cos(2 * X[:,0]) + np.cos(3 * X[:,1])

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection = '3d')
ax.scatter(X[:, 0], X[:, 1], y)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape = (2,)),
    tf.keras.layers.Dense(128, activation = 'relu'),
    tf.keras.layers.Dense(1)
])

# %%
opt = tf.keras.optimizers.Adam(learning_rate = 0.01)
model.compile(optimizer = opt, loss = 'mse')
r = model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0758
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9738
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9604
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8976
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8738
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8617
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7748
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7352
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7094
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6260
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6426
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5575
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5677
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5521
# Epoch 15/100
# ...

# %%
plt.plot(r.history['loss'], label = 'loss')
plt.legend()

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.scatter(X[:, 0], X[:, 1] , y)

line = np.linspace(-3, 3, 50)
xx, yy = np.meshgrid(line,line)
Xgrid = np.vstack((xx.flatten(),yy.flatten())).T
y_hat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:, 0], Xgrid[:, 1], y_hat, linewidth=0.1, antialiased=True)
plt.show()
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.scatter(X[:,0],X[:,1],y)

line = np.linspace(-10,10,500)
xx,yy = np.meshgrid(line,line)
Xgrid = np.vstack((xx.flatten(),yy.flatten())).T
y_hat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0],Xgrid[:,1],y_hat,linewidth=0.1,antialiased=True)
plt.show()
# Out:
# 7813/7813 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
